# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
#
# **Привет!**
#
# Меня зовут Алексей Манелюк, я буду проверять твой проект. Предлагаю общаться на "ты" 😉, но если неудобно - скажи и будем на "вы".
#
# Моя основная цель - не указать на совершенные тобой ошибки, а поделиться своим опытом и помочь тебе стать крутым аналитиком данных. Тобой проделана большая работа над проектом,
# но давай сделаем его еще лучше. В тексте проекта ты увидишь мои комментарии, пожалуйста не удаляй и не изменяй их. У комментариев могут быть приписки **V2**, **V3** и т.д., которые соответствуют версии проверки. Я буду использовать цветовую разметку:
# <p>
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Так выделены самые важные замечания. Без их отработки я не смогу принять проект. </div>
#
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Так выделены небольшие замечания. Не более трёх таких замечаний допустимы. Если их много - постарайся исправить их.</div>
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Так выделены все остальные комментарии.</div>
#
# Предлагаю работать в диалоге: если что-то дорабатываешь или отвечаешь на мой комментарий - пиши об этом и мне будет удобней, если ты выделишь свои комментарии:
# <p>
# <div class="alert-info">
# <b>Комментарий студента</b>
#
# Например, так.</div>
#
# Все это поможет мне быстрее принять твой проект.</div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-первый-осмотр:" data-toc-modified-id="Загрузка-данных-и-первый-осмотр:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных и первый осмотр:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Предобработка-данных:" data-toc-modified-id="Предобработка-данных:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных:</a></span><ul class="toc-item"><li><span><a href="#Обработка-колонки-last_price:" data-toc-modified-id="Обработка-колонки-last_price:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка колонки last_price:</a></span></li><li><span><a href="#Обработка-колонки-total_area:" data-toc-modified-id="Обработка-колонки-total_area:-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка колонки total_area:</a></span></li><li><span><a href="#Обработка-колонки-living_area:" data-toc-modified-id="Обработка-колонки-living_area:-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обработка колонки living_area:<br></a></span></li><li><span><a href="#Обработка-колонки-kitchen_area:" data-toc-modified-id="Обработка-колонки-kitchen_area:-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка колонки kitchen_area:<br></a></span></li><li><span><a href="#Обработка-колонки-ceiling_height:" data-toc-modified-id="Обработка-колонки-ceiling_height:-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Обработка колонки ceiling_height:</a></span></li><li><span><a href="#Обработка-колонки-floors_total:" data-toc-modified-id="Обработка-колонки-floors_total:-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Обработка колонки floors_total:</a></span></li><li><span><a href="#Обработка-колонки-locality_name:" data-toc-modified-id="Обработка-колонки-locality_name:-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Обработка колонки locality_name:<br></a></span></li><li><span><a href="#Обработка-колонки-cityCenters_nearest:" data-toc-modified-id="Обработка-колонки-cityCenters_nearest:-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Обработка колонки cityCenters_nearest:<br></a></span></li><li><span><a href="#Обработка-колонки-first_day_exposition:" data-toc-modified-id="Обработка-колонки-first_day_exposition:-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Обработка колонки first_day_exposition:<br></a></span></li><li><span><a href="#Обработка-колонки-days_exposition:" data-toc-modified-id="Обработка-колонки-days_exposition:-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Обработка колонки days_exposition:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу:" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу:-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу:</a></span><ul class="toc-item"><li><span><a href="#Расчет-цены-квадратного-метра:" data-toc-modified-id="Расчет-цены-квадратного-метра:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Расчет цены квадратного метра:</a></span></li><li><span><a href="#Добавление-колонки-с-днем-недели,-месяцем-и-годом-публикации-объявления:" data-toc-modified-id="Добавление-колонки-с-днем-недели,-месяцем-и-годом-публикации-объявления:-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Добавление колонки с днем недели, месяцем и годом публикации объявления:</a></span></li><li><span><a href="#Категоризация-этажа-квартиры-(первый,-последний,-другой):" data-toc-modified-id="Категоризация-этажа-квартиры-(первый,-последний,-другой):-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Категоризация этажа квартиры (первый, последний, другой):</a></span></li><li><span><a href="#Расчет-соотношения-жилой-и-общей-площади,-площади-кухни-к-общей:" data-toc-modified-id="Расчет-соотношения-жилой-и-общей-площади,-площади-кухни-к-общей:-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Расчет соотношения жилой и общей площади, площади кухни к общей:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных:" data-toc-modified-id="Исследовательский-анализ-данных:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных:</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-Построение-гистограмм-для-каждого-параметра:" data-toc-modified-id="Изучение-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-Построение-гистограмм-для-каждого-параметра:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров: площадь, цена, число комнат, высота потолков. Построение гистограмм для каждого параметра:</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметра---площадь:" data-toc-modified-id="Изучение-параметра---площадь:-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Изучение параметра - площадь:</a></span></li><li><span><a href="#Изучение-параметра---цена:" data-toc-modified-id="Изучение-параметра---цена:-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Изучение параметра - цена:</a></span></li><li><span><a href="#Изучение-параметра---комнаты:" data-toc-modified-id="Изучение-параметра---комнаты:-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Изучение параметра - комнаты:</a></span></li><li><span><a href="#Изучение-параметра---высота-потолка:" data-toc-modified-id="Изучение-параметра---высота-потолка:-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Изучение параметра - высота потолка:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Изучение-время-продажи-квартиры.-Построение-гистограммы.-Расчет-среднего-и-медианы.-Анализ-процесса-продажи:" data-toc-modified-id="Изучение-время-продажи-квартиры.-Построение-гистограммы.-Расчет-среднего-и-медианы.-Анализ-процесса-продажи:-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучение время продажи квартиры. Построение гистограммы. Расчет среднего и медианы. Анализ процесса продажи:</a></span><ul class="toc-item"><li><span><a href="#Изучение-время-продажи-квартиры:" data-toc-modified-id="Изучение-время-продажи-квартиры:-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Изучение время продажи квартиры:</a></span></li><li><span><a href="#Построение-гистограммы:" data-toc-modified-id="Построение-гистограммы:-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Построение гистограммы:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Изучение-влияния-факторов-на-стоимость-квартиры.-Изучение-зависимости-цены-от-площади,-числа-комнат,-удалённости-от-центра.-Изучение-зависимости-цены-от-того,-на-каком-этаже-расположена-квартира.--Изучение-зависимости-от-даты-размещения:-дня-недели,-месяца-и-года:" data-toc-modified-id="Изучение-влияния-факторов-на-стоимость-квартиры.-Изучение-зависимости-цены-от-площади,-числа-комнат,-удалённости-от-центра.-Изучение-зависимости-цены-от-того,-на-каком-этаже-расположена-квартира.--Изучение-зависимости-от-даты-размещения:-дня-недели,-месяца-и-года:-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Изучение влияния факторов на стоимость квартиры. Изучение зависимости цены от площади, числа комнат, удалённости от центра. Изучение зависимости цены от того, на каком этаже расположена квартира.  Изучение зависимости от даты размещения: дня недели, месяца и года:</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-от-площади:" data-toc-modified-id="Зависимость-цены-от-площади:-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Зависимость цены от площади:</a></span></li><li><span><a href="#Зависимость-цены-от-количества-комнат:" data-toc-modified-id="Зависимость-цены-от-количества-комнат:-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Зависимость цены от количества комнат:</a></span></li><li><span><a href="#Зависимость-цены-от-удаленности-от-центра:" data-toc-modified-id="Зависимость-цены-от-удаленности-от-центра:-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Зависимость цены от удаленности от центра:</a></span></li><li><span><a href="#Зависимость-цены-от-этажа:" data-toc-modified-id="Зависимость-цены-от-этажа:-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Зависимость цены от этажа:</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения:-дня-недели:" data-toc-modified-id="Зависимость-цены-от-даты-размещения:-дня-недели:-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Зависимость цены от даты размещения: дня недели:</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения:-месяца:" data-toc-modified-id="Зависимость-цены-от-даты-размещения:-месяца:-4.3.6"><span class="toc-item-num">4.3.6&nbsp;&nbsp;</span>Зависимость цены от даты размещения: месяца:</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения:-года:" data-toc-modified-id="Зависимость-цены-от-даты-размещения:-года:-4.3.7"><span class="toc-item-num">4.3.7&nbsp;&nbsp;</span>Зависимость цены от даты размещения: года:</a></span></li><li><span><a href="#Вывод-всех-корреляции:" data-toc-modified-id="Вывод-всех-корреляции:-4.3.8"><span class="toc-item-num">4.3.8&nbsp;&nbsp;</span>Вывод всех корреляции:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.3.9"><span class="toc-item-num">4.3.9&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Отбор-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Расчет-средней-цены-квадратного-метра-в-этих-населённых-пунктах.-Выделение-населённых-пунктов-с-самой-высокой-и-низкой-стоимостью-жилья." data-toc-modified-id="Отбор-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Расчет-средней-цены-квадратного-метра-в-этих-населённых-пунктах.-Выделение-населённых-пунктов-с-самой-высокой-и-низкой-стоимостью-жилья.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Отбор 10 населённых пунктов с наибольшим числом объявлений. Расчет средней цены квадратного метра в этих населённых пунктах. Выделение населённых пунктов с самой высокой и низкой стоимостью жилья.</a></span><ul class="toc-item"><li><span><a href="#Вывод-списка-из-10-населённых-пунктов-с-наибольшим-числом-объявлений:" data-toc-modified-id="Вывод-списка-из-10-населённых-пунктов-с-наибольшим-числом-объявлений:-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Вывод списка из 10 населённых пунктов с наибольшим числом объявлений:</a></span></li><li><span><a href="#Расчет-средней-цены-квадратного-метра-в-этих-населённых-пунктах:" data-toc-modified-id="Расчет-средней-цены-квадратного-метра-в-этих-населённых-пунктах:-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Расчет средней цены квадратного метра в этих населённых пунктах:</a></span></li><li><span><a href="#Построение-гистограммы:" data-toc-modified-id="Построение-гистограммы:-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Построение гистограммы:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Определение-центральной-зоны-Санкт-Петербурга:" data-toc-modified-id="Определение-центральной-зоны-Санкт-Петербурга:-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Определение центральной зоны Санкт-Петербурга:</a></span><ul class="toc-item"><li><span><a href="#Создание-выборки-по-городу-Санкт-Петербург-и-расчет-отдаленности-от-центра-города-в-километрах:" data-toc-modified-id="Создание-выборки-по-городу-Санкт-Петербург-и-расчет-отдаленности-от-центра-города-в-километрах:-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Создание выборки по городу Санкт-Петербург и расчет отдаленности от центра города в километрах:</a></span></li><li><span><a href="#Построение-графика-зависимости-цены-от-от-удаленности-квартиры-от-центра:" data-toc-modified-id="Построение-графика-зависимости-цены-от-от-удаленности-квартиры-от-центра:-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Построение графика зависимости цены от от удаленности квартиры от центра:</a></span></li><li><span><a href="#Расчет-средней-цены-для-каждого-километра:" data-toc-modified-id="Расчет-средней-цены-для-каждого-километра:-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>Расчет средней цены для каждого километра:</a></span></li><li><span><a href="#Построение-графика-зависимости-стоимости-квадратного-метра-от-удаленности-квартиры-от-центра:" data-toc-modified-id="Построение-графика-зависимости-стоимости-квадратного-метра-от-удаленности-квартиры-от-центра:-4.5.4"><span class="toc-item-num">4.5.4&nbsp;&nbsp;</span>Построение графика зависимости стоимости квадратного метра от удаленности квартиры от центра:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.5.5"><span class="toc-item-num">4.5.5&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Анализ-сегмента-квартир-в-центре.-Изучение-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-Изучение-факторов-влияющих-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Анализ-отличий-от-общих-выводов-по-всей-базе:" data-toc-modified-id="Анализ-сегмента-квартир-в-центре.-Изучение-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-Изучение-факторов-влияющих-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Анализ-отличий-от-общих-выводов-по-всей-базе:-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Анализ сегмента квартир в центре. Изучение параметров: площадь, цена, число комнат, высота потолков. Изучение факторов влияющих на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Анализ отличий от общих выводов по всей базе:</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметра---площадь:" data-toc-modified-id="Изучение-параметра---площадь:-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Изучение параметра - площадь:</a></span></li><li><span><a href="#Изучение-параметра---цена:" data-toc-modified-id="Изучение-параметра---цена:-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>Изучение параметра - цена:</a></span></li><li><span><a href="#Изучение-параметра---комнаты:" data-toc-modified-id="Изучение-параметра---комнаты:-4.6.3"><span class="toc-item-num">4.6.3&nbsp;&nbsp;</span>Изучение параметра - комнаты:</a></span></li><li><span><a href="#Изучение-параметра---высота-потолка:" data-toc-modified-id="Изучение-параметра---высота-потолка:-4.6.4"><span class="toc-item-num">4.6.4&nbsp;&nbsp;</span>Изучение параметра - высота потолка:</a></span></li><li><span><a href="#Зависимость-цены-от-количества-комнат:" data-toc-modified-id="Зависимость-цены-от-количества-комнат:-4.6.5"><span class="toc-item-num">4.6.5&nbsp;&nbsp;</span>Зависимость цены от количества комнат:</a></span></li><li><span><a href="#Зависимость-цены-от-этажа:" data-toc-modified-id="Зависимость-цены-от-этажа:-4.6.6"><span class="toc-item-num">4.6.6&nbsp;&nbsp;</span>Зависимость цены от этажа:</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения---дня-недели:" data-toc-modified-id="Зависимость-цены-от-даты-размещения---дня-недели:-4.6.7"><span class="toc-item-num">4.6.7&nbsp;&nbsp;</span>Зависимость цены от даты размещения - дня недели:</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения---месяца:" data-toc-modified-id="Зависимость-цены-от-даты-размещения---месяца:-4.6.8"><span class="toc-item-num">4.6.8&nbsp;&nbsp;</span>Зависимость цены от даты размещения - месяца:</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения---года:" data-toc-modified-id="Зависимость-цены-от-даты-размещения---года:-4.6.9"><span class="toc-item-num">4.6.9&nbsp;&nbsp;</span>Зависимость цены от даты размещения - года:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.6.10"><span class="toc-item-num">4.6.10&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Правильно, что во вступлении пишешь бриф и цель исследования. Можно вступление немного расширить, добавив план работы и описание данных.</div>

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# ### Загрузка данных и первый осмотр:

# %%
import pandas as pd

data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# В результате анализа проекты выяснили какие колонки понадобятся и создали датафрейм из задействованных колонок:

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# А как ты узнал, какие столбцы тебе понадобятся для анализа?</div>

# %% [markdown]
# <p>
# <div class="alert-info">
# <b>Любая работа делается в несколько итераций, соответственно я узнал это из первых итераций.<br>
# Принимающему результат, на мой взгляд, абсолютно все равно, на колонки которые не используются в исследовании, поэтому они были исключены</b>

# %%
data = data[[ 'last_price', 'rooms', 'total_area', 'living_area', 'kitchen_area', 'ceiling_height', 
        'floors_total', 'floor', 'locality_name', 'cityCenters_nearest','first_day_exposition', 'days_exposition']]

display(data.head())
data.info()
# Out:
#    last_price  rooms  total_area  living_area  kitchen_area  ceiling_height  \
# 0  13000000.0      3       108.0         51.0          25.0            2.70
# 1   3350000.0      1        40.4         18.6          11.0             NaN
# 2   5196000.0      2        56.0         34.3           8.3             NaN
# 3  64900000.0      3       159.0          NaN           NaN             NaN
# 4  10000000.0      2       100.0         32.0          41.0            3.03
#
#    floors_total  floor    locality_name  cityCenters_nearest  \
# 0          16.0      8  Санкт-Петербург              16028.0
# 1          11.0      1   посёлок Шушары              18603.0
# 2           5.0      4  Санкт-Петербург              13933.0
# 3          14.0      9  Санкт-Петербург               6800.0
# 4          14.0     13  Санкт-Петербург               8098.0
#
#   first_day_exposition  days_exposition
# 0  2019-03-07T00:00:00              NaN
# 1  2018-12-04T00:00:00             81.0
# ...

# %% [markdown]
# ### Вывод:

# %% [markdown]
# **При первой загрузке данных обнаружили отсутствие значений в следующих колонках:**<br>
# - 'ceiling_height';
# - 'floors_total';
# - 'locality_name';
# - 'cityCenters_nearest';
# - 'days_exposition';
# - 'living_area';
# - 'kitchen_area'.
#
# **Значения нуждающиеся в дополнительном анализе и корректировке:**<br>
# - 'ceiling_height';
# - 'cityCenters_nearest';
# - 'last_price'.
#
# **Значении в которых необходимо заменить тип:**<br>
# - floors_total;
# - first_day_exposition;
# - days_exposition.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Данные загружены верно, получена первая общая информация о датафрейме. 🚀
#
# Правильно, что пишешь вывод в конце шага.</div>

# %% [markdown]
# ## Предобработка данных:

# %% [markdown]
# ### Обработка колонки last_price:

# %% [markdown]
# Проверим на экстремально низкие и экстремально высокие цены: <br>
# Выедем экстремально низкие цены:

# %%
data[data['last_price'] <= 400000]
# Out:
#       last_price  rooms  total_area  living_area  kitchen_area  \
# 8793     12190.0      2       109.0         32.0          40.5
#
#       ceiling_height  floors_total  floor    locality_name  \
# 8793            2.75          25.0     25  Санкт-Петербург
#
#       cityCenters_nearest first_day_exposition  days_exposition
# 8793               9176.0  2019-03-20T00:00:00              8.0

# %% [markdown]
# Экстремально низкое значение цены, это очевидно ошибка данных, удаляем эту строку

# %%
data = data[data['last_price'] >= 400000]

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# А может забыли дописать ноль.</div>

# %% [markdown]
# <p>
# <div class="alert-info">
# <b>я об этом думал, но квартира в 100 кв.м. за миллион в 10 км от центра слишком приятный сон:) Но вот о двух нолях я не подумал.. 12 миллионов конечно тоже не очень много за такую квартиру, но уже ближе:)</b>

# %% [markdown]
# Выведем экстремально высокие цены:

# %%
data[data['last_price'] >= 200000000]
# Out:
#         last_price  rooms  total_area  living_area  kitchen_area  \
# 1436   330000000.0      3       190.0         95.0          40.0
# 5893   230000000.0      6       500.0          NaN          40.0
# 12971  763000000.0      7       400.0        250.0           NaN
# 13749  240000000.0      6       410.0        218.0          40.0
# 14706  401300000.0      5       401.0        204.0          24.0
# 15651  300000000.0      7       618.0        258.0          70.0
# 16461  245000000.0      6       285.7        182.8          29.8
# 19540  420000000.0     12       900.0        409.7         112.0
# 22831  289238400.0      2       187.5         63.7          30.2
#
#        ceiling_height  floors_total  floor    locality_name  \
# 1436             3.50           7.0      5  Санкт-Петербург
# 5893              NaN           7.0      7  Санкт-Петербург
# 12971             NaN          10.0     10  Санкт-Петербург
# 13749            3.40           7.0      7  Санкт-Петербург
# ...

# %% [markdown]
# Квартиры с большими ценами вполне могут столько стоить, так как либо в центре либо с большой площадью

# %% [markdown]
# ### Обработка колонки total_area:

# %% [markdown]
# Проанализируем самые дорогие объекты с маленькой площадью:

# %%
display(data[data['total_area'] <= 20].sort_values(by='last_price', ascending=False).head(10))
# Out:
#        last_price  rooms  total_area  living_area  kitchen_area  \
# 19807   3800000.0      1        13.0         10.0           NaN
# 9157    3400000.0      1        17.6         15.0           NaN
# 4542    3300000.0      1        18.0          9.0           NaN
# 4077    3000000.0      2        20.0         13.0           5.6
# 8873    2950000.0      1        20.0         14.0           6.0
# 8886    2450000.0      0        15.5         10.0           NaN
# 19904   2400000.0      1        12.0         10.0           NaN
# 17860   2385000.0      1        20.0          NaN           NaN
# 19477   2300000.0      0        20.0         16.0           NaN
# 8454    2250000.0      0        19.0          NaN           NaN
#
#        ceiling_height  floors_total  floor    locality_name  \
# 19807             NaN           5.0      3  Санкт-Петербург
# 9157              NaN           5.0      2  Санкт-Петербург
# 4542             3.50           5.0      2  Санкт-Петербург
# ...

# %% [markdown]
# Все эти объекты находятся в центре, поэтому вполне нормально, что они стоят дорого.

# %% [markdown]
# Проанализируем самые дешевые объекты с большой площадью:

# %%
display(data[data['total_area'] >= 200].sort_values(by='last_price', ascending=True).head(10))
# Out:
#        last_price  rooms  total_area  living_area  kitchen_area  \
# 2462    7900000.0      7      201.50          NaN           NaN
# 7399   11000000.0      5      230.00          NaN           NaN
# 22038  11940000.0      5      206.00        160.0          26.0
# 2489   12500000.0      3      255.00        153.9         100.7
# 6107   13200000.0      4      236.00         78.0          19.0
# 19964  13545000.0      3      238.26          NaN          10.2
# 679    13700000.0      4      200.00         90.0          35.0
# 11087  14000000.0      6      320.00        190.0          28.0
# 13931  14300000.0      5      250.00        119.0          21.0
# 22197  14350000.0      4      204.00        110.4          23.9
#
#        ceiling_height  floors_total  floor      locality_name  \
# 2462              NaN           2.0      2  посёлок Парголово
# 7399             2.50           2.0      2   деревня Хязельки
# 22038            3.50           6.0      3    Санкт-Петербург
# ...

# %% [markdown]
# Видим что цены вполне соотносятся с характеристиками объектов нежвижиммости.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Молодец, что провел дополнительный анализ цены и площади.</div>

# %% [markdown]
# ### Обработка колонки living_area:<br>
# Проверим наличие пропущенных значений:

# %%
print('Пропущенные значения: {:.2%}'.format(data['last_price'][data['living_area'].isnull()].count() / len(data)))
# Out:
# Пропущенные значения: 8.03%

# %% [markdown]
# Заполним пропуски средним отношением жилой площади к общей площади:

# %%
liv_a_to_tot_a = data['living_area'][data['living_area'].notnull()].sum() / data['total_area'][data['living_area'].notnull()].sum()
data.loc[data['living_area'].isnull(), 'living_area'] = liv_a_to_tot_a * data['total_area']

# %% [markdown]
# Приводим значения к единому формату по количеству знаков после запятой:

# %%
data['living_area'] = data['living_area'].round(1)

# %% [markdown]
# ### Обработка колонки kitchen_area:<br>
# Проверим наличие пропущенных значений:

# %%
print('Пропущенные значения: {:.2%}'.format(data['last_price'][data['kitchen_area'].isnull()].count() / len(data)))
# Out:
# Пропущенные значения: 9.61%

# %% [markdown]
# Заполним пропуски средним отношением площади кухни к общей площади:

# %%
kitch_a_to_tot_a = data['kitchen_area'][data['kitchen_area'].notnull()].sum() / data['total_area'][data['kitchen_area'].notnull()].sum()
data.loc[data['kitchen_area'].isnull(), 'kitchen_area'] = kitch_a_to_tot_a * data['total_area']

# %% [markdown]
# Приводим значения к единому формату по количеству знаков после запятой:

# %%
data['kitchen_area'] = data['kitchen_area'].round(1)

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Это правильное решение по обработке пропусков в этих столбцах.
#
# Оценить процент пропущенных данных сразу во всех столбцах можно таким способом: `df.isna().mean()`</div>

# %% [markdown]
# ### Обработка колонки ceiling_height:

# %% [markdown]
# В СНиП https://docs.cntd.ru/document/1200035248 в пункте 5.8 указывается минимальная высота потолка 2.5 метра, данное значение надо иметь ввиду как ориентир, но учитывать что есть старые здания построенные не по этому документу.

# %% [markdown]
# Определяем 2 пула квартир один с высотой потолка более 5 метров и второй с высотой потолка более 6 метров, и строим диаграмму по площади этих квартир:

# %%
from matplotlib import pyplot
data['total_area'][data['ceiling_height'] > 5].hist(figsize=(15,6))
data['total_area'][data['ceiling_height'] > 6].hist(figsize=(15,6))
pyplot.legend(['Квартиры с высотой потолка более 5 метров в высоту','Квартиры с высотой потолка более 6 метров в высоту'])

# %% [markdown]
# По данной гистограмме видим, что у квартир с высотой потолка более 6 метров абсолютно типичное распределение площадей для квартир из первого сектора от 0 до 100 кв.м., соответственно делаем вывод, что данные в эти квартиры занесены с ошибкой, соответственно их необходимо скорректировать на медианное значение 1 сектора.<br>
# Медианное значение было выбрано по причине того, что большинство квартир имеет стандартную высоту потолка, поэтому в расчет будет не правильно включать дворцы и частные дома с высокими потолками.<br>
# Так же в пользу медианного значения говорит распределение площади квартиры, площадь не более 100 квадратных метров говорит о том что это среднестатистическая квартира в обычном доме где стандартные потолки.<br>
# Соответственно заменяем медианным значением:

# %%
data.loc[data['ceiling_height'] > 6, 'ceiling_height'] = data['ceiling_height'][(data['total_area'] >= 0) & (data['total_area'] < 100)].median()

# %% [markdown]
# Работа с отсутствующими значениями:

# %% [markdown]
# Проверим количество отсутствующих значений:

# %%
print('Пропущенные значения: {:.2%}'.format(data['last_price'][data['ceiling_height'].isnull()].count() / len(data)))
# Out:
# Пропущенные значения: 38.80%

# %% [markdown]
# Пропущенных значений много соответственно заполняем по логике, что чем больше квартира, тем выше потолки, поэтому для наглядности построим гистограмму распределения площадей в квартирах с отсутствующими значениями высоты потолков:

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# А почему ты считаешь, что такая зависимость есть?</div>

# %% [markdown]
# <p>
# <div class="alert-info">
# <b>Я исходил из того что чем больше площадь, тем более дорогая постройка, а люди с достатком выбирают более просторные помещения во всех измерениях:<br>
# До 100 кв.м. все понятно это стандартная застройка с регламентированной высотой потолока в большинстве своем;<br>
# 100 - 200 кв.м. это элитные квартиры или таунхаусы, квартиры чаще всего в центре города, пройдясь по центру москвы и СПБ сразу видно что там потолок выше;<br>
# а 200 - 600 кв.м. можно было выделить в единый сегмент сверх дорогого элитного видового жилья, например возле кремля и москве сити<br>
# https://www.cian.ru/sale/flat/260030358/<br>
# https://www.cian.ru/sale/flat/260030351/.<br>
# PS если честно я глянул циан сейчас и действительно момент спорный, возможно есть смысл взять не зависимость от площади, а от цены и проделать анализ, но это уже надо ставить как отдельную цель исследования.
# </b>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Согласен, логично. Но мы рассматриваем Питер, там в центре старый фонд и такой связи может не быть.</div>

# %%
data['total_area'][data['ceiling_height'].isnull()].hist(bins=50, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим нормальное распределение, что говорит о том что это типичные жилые помещения, поэтому разделяем логически на 6 секторов и посчитаем по ним медианы:

# %%
print('Медиана по 1 сектору с площадью от 0 до 100 кв.м. -', data['ceiling_height'][(data['total_area'] >= 0) & (data['total_area'] < 100)].median())
print('Медиана по 2 сектору с площадью от 100 до 200 кв.м. -',data['ceiling_height'][(data['total_area'] >= 100) & (data['total_area'] < 200)].median())
print('Медиана по 3 сектору с площадью от 200 до 300 кв.м. -',data['ceiling_height'][(data['total_area'] >= 200) & (data['total_area'] < 300)].median())
print('Медиана по 4 сектору с площадью от 300 до 400 кв.м. -',data['ceiling_height'][(data['total_area'] >= 300) & (data['total_area'] < 400)].median())
print('Медиана по 5 сектору с площадью от 400 до 500 кв.м. -',data['ceiling_height'][(data['total_area'] >= 400) & (data['total_area'] < 500)].median())
print('Медиана по 6 сектору с площадью от 500 до 600 кв.м. -',data['ceiling_height'][(data['total_area'] >= 500)].median())
# Out:
# Медиана по 1 сектору с площадью от 0 до 100 кв.м. - 2.6
# Медиана по 2 сектору с площадью от 100 до 200 кв.м. - 3.0
# Медиана по 3 сектору с площадью от 200 до 300 кв.м. - 3.33
# Медиана по 4 сектору с площадью от 300 до 400 кв.м. - 3.32
# Медиана по 5 сектору с площадью от 400 до 500 кв.м. - 3.175
# Медиана по 6 сектору с площадью от 500 до 600 кв.м. - 3.45

# %% [markdown]
# Видим что наше предположение о том чем больше площадь тем выше потолок верно.<br>
# Применяем по секторам медианную высоту:

# %%
data.loc[(data['ceiling_height'].isnull()) & (data['total_area'] >= 0) & (data['total_area'] < 100), 'ceiling_height'] = data['ceiling_height'][(data['total_area'] >= 0) & (data['total_area'] < 100)].median()  
data.loc[(data['ceiling_height'].isnull()) & (data['total_area'] >= 100) & (data['total_area'] < 200), 'ceiling_height'] = data['ceiling_height'][(data['total_area'] >= 100) & (data['total_area'] < 200)].median()
data.loc[(data['ceiling_height'].isnull()) & (data['total_area'] >= 200) & (data['total_area'] < 300), 'ceiling_height'] = data['ceiling_height'][(data['total_area'] >= 200) & (data['total_area'] < 300)].median() 
data.loc[(data['ceiling_height'].isnull()) & (data['total_area'] >= 300) & (data['total_area'] < 400), 'ceiling_height'] = data['ceiling_height'][(data['total_area'] >= 300) & (data['total_area'] < 400)].median()
data.loc[(data['ceiling_height'].isnull()) & (data['total_area'] >= 400) & (data['total_area'] < 500), 'ceiling_height'] = data['ceiling_height'][(data['total_area'] >= 400) & (data['total_area'] < 500)].median()
data.loc[(data['ceiling_height'].isnull()) & (data['total_area'] >= 500), 'ceiling_height'] = data['ceiling_height'][(data['total_area'] >= 500)].median()
data['ceiling_height'].describe()
# Out:
# count    23698.000000
# mean         2.688708
# std          0.234538
# min          1.000000
# 25%          2.600000
# 50%          2.600000
# 75%          2.700000
# max          6.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Судя по получившимся значениям среднего и медианы - это рабочий вариант. Хотя для меня такая взаимосвязь не очевидна. Посмотри, получается что потолки в кв. 400-500 кв.м меньше чем в 200-300.</div>

# %% [markdown]
# ### Обработка колонки floors_total:

# %%
print('Пропущенные значения: {:.2%}'.format(data['floors_total'].isna().sum() / len(data)))
data[data['floors_total'].isnull()].head()
# Out:
# Пропущенные значения: 0.36%
#       last_price  rooms  total_area  living_area  kitchen_area  \
# 186   11640000.0      2        65.2         30.8          12.0
# 237    2438033.0      1        28.1         20.8           4.9
# 457    9788348.0      2        70.8         38.4          10.6
# 671    6051191.0      3        93.6         47.1          16.8
# 1757   3600000.0      1        39.0         22.4           6.8
#
#       ceiling_height  floors_total  floor    locality_name  \
# 186              2.6           NaN      4  Санкт-Петербург
# 237              2.6           NaN      1  Санкт-Петербург
# 457              2.6           NaN     12  Санкт-Петербург
# 671              2.6           NaN      8  Санкт-Петербург
# 1757             2.6           NaN      9  Санкт-Петербург
#
#       cityCenters_nearest first_day_exposition  days_exposition
# 186               12373.0  2018-10-02T00:00:00             49.0
# 237               17369.0  2016-11-23T00:00:00            251.0
# ...

# %% [markdown]
# Предполагаю, что люди не указали последний этаж, потому что их этаж последний.<br>
# Более того пропущеных значений 0.36%, поэтому этим значениями можно пренебречь.

# %%
data.loc[data['floors_total'].isnull(), 'floors_total'] = data.loc[data['floors_total'].isnull(), 'floor']

# %%
data['floors_total'].describe()
# Out:
# count    23698.000000
# mean        10.670858
# std          6.595284
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Для удобства анализа заменяем тип на int64:

# %%
data = data.astype({'floors_total': 'int64'})
print('Тип колонки:', data['floors_total'].dtype)
# Out:
# Тип колонки: int64

# %% [markdown]
# ### Обработка колонки locality_name:<br>
# Проверим наличие пропущенных значений:

# %%
print('Пропущенные значения: {:.2%}'.format(data['first_day_exposition'][data['locality_name'].isnull()].count() / len(data)))
# Out:
# Пропущенные значения: 0.21%

# %% [markdown]
# Так как пропущенных значений мало, методика замена данных будет очень сложна, а их удаление не повлияет на ход исследования, то принимаем решение удалить эти строки.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Это верное решение - удалить пропуски, если восстановить их сложно и количество не очень велико.</div>

# %%
data = data[data['locality_name'].notnull()]
data['locality_name'].describe()
# Out:
# count               23649
# unique                364
# top       Санкт-Петербург
# freq                15720
# Name: locality_name, dtype: object

# %% [markdown]
# Все названия переводим в нижний регистр, что бы не было разночтений при группировании:

# %%
data['locality_name'] = data['locality_name'].str.lower()

# %% [markdown]
# ### Обработка колонки cityCenters_nearest:<br>
# Посчитаем количество отсутствующих значений и выведем в каких locality_name не заполнено это поле:

# %%
print('Пропущенные значения: {:.2%}'.format(data['first_day_exposition'][data['cityCenters_nearest'].isna()].count()/ len(data)))

data['locality_name'][data['cityCenters_nearest'].isnull()].unique()
# Out:
# Пропущенные значения: 23.30%
# array(['городской посёлок янино-1', 'посёлок мурино', 'сертолово',
#        'деревня кудрово', 'коммунар',
#        'поселок городского типа красный бор', 'гатчина', 'поселок мурино',
#        'деревня фёдоровское', 'выборг', 'кировск',
#        'деревня новое девяткино', 'санкт-петербург',
#        'посёлок городского типа лебяжье',
#        'посёлок городского типа сиверский', 'поселок молодцово',
#        'поселок городского типа кузьмоловский',
#        'садовое товарищество новая ропша', 'деревня пикколово',
#        'всеволожск', 'волхов', 'кингисепп', 'приозерск',
#        'деревня куттузи', 'посёлок аннино',
#        'поселок городского типа ефимовский', 'посёлок плодовое',
#        'деревня заклинье', 'поселок торковичи', 'поселок первомайское',
#        'сясьстрой', 'деревня старая', 'деревня лесколово',
#        'посёлок новый свет', 'сланцы', 'село путилово', 'ивангород',
#        'мурино', 'шлиссельбург', 'никольское', 'сосновый бор',
# ...

# %% [markdown]
# Видим что в колонке cityCenters_nearest отсутствуют значения в местах, где нет центра города, соответственно заменяем отсутствующие значения на 0:

# %%
data.loc[data['cityCenters_nearest'].isnull(), 'cityCenters_nearest'] = 0

# %%
data[data['cityCenters_nearest'] == 0].head(5)
# Out:
#     last_price  rooms  total_area  living_area  kitchen_area  ceiling_height  \
# 5    2890000.0      1       30.40         14.4           9.1            2.60
# 8    2900000.0      1       33.16         15.4           8.8            2.60
# 12   3890000.0      2       54.00         30.0           9.0            2.60
# 22   5000000.0      2       58.00         30.0          11.0            2.75
# 30   2200000.0      1       32.80         18.8           5.7            2.60
#
#     floors_total  floor              locality_name  cityCenters_nearest  \
# 5             12      5  городской посёлок янино-1                  0.0
# 8             27     26             посёлок мурино                  0.0
# 12             5      5                  сертолово                  0.0
# 22            25     15            деревня кудрово                  0.0
# 30             9      2                   коммунар                  0.0
#
#    first_day_exposition  days_exposition
# ...

# %% [markdown]
# Для удобства анализа заменяем тип на int64:

# %%
data = data.astype({'cityCenters_nearest': 'int64'})
print('Тип колонки:', data['cityCenters_nearest'].dtype)
# Out:
# Тип колонки: int64

# %%
data['cityCenters_nearest'].describe()
# Out:
# count    23649.000000
# mean     10889.501459
# std       9635.728770
# min          0.000000
# 25%       2242.000000
# 50%      11250.000000
# 75%      15247.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# ### Обработка колонки first_day_exposition:<br>
# Проверим наличие пропущенных значений:

# %%
print('Пропущенные значения: {:.2%}'.format(data['last_price'][data['first_day_exposition'].isnull()].count() / len(data)))
# Out:
# Пропущенные значения: 0.00%

# %% [markdown]
# Для удобства анализа зменяем формат на

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y%m%dT%H:%M:%S')

# %%
print('Тип колонки:', data['first_day_exposition'].dtype)
# Out:
# Тип колонки: datetime64[ns]

# %% [markdown]
# ### Обработка колонки days_exposition:

# %%
print('Пропущенные значения: {:.2%}'.format(data['first_day_exposition'][data['days_exposition'].isnull()].count() / len(data)))
# Out:
# Пропущенные значения: 13.45%

# %%
data[data['days_exposition'].isnull()].head()
# Out:
#     last_price  rooms  total_area  living_area  kitchen_area  ceiling_height  \
# 0   13000000.0      3       108.0         51.0          25.0            2.70
# 7    7915000.0      2        71.6         41.1          18.9            2.60
# 44   5350000.0      1        40.0         22.9           7.0            2.60
# 45   5200000.0      2        50.6         30.3           7.0            2.65
# 46   6600000.0      2        52.1         29.7           8.3            2.60
#
#     floors_total  floor    locality_name  cityCenters_nearest  \
# 0             16      8  санкт-петербург                16028
# 7             24     22  санкт-петербург                11634
# 44            22      3  санкт-петербург                11603
# 45             9      7  санкт-петербург                12872
# 46            24      9  санкт-петербург                12702
#
#    first_day_exposition  days_exposition
# 0            2019-03-07              NaN
# 7            2019-04-18              NaN
# ...

# %% [markdown]
# Для данной колонки не существует корректного механизма замены, если мы заменим средним или медианным значением то мы сильно повлияем на результат исследования, который сместит фокус с учетом большого количества усредненных значений.<br>
# Если мы распределим значения согласно любому механизму распределения то он так же неизвестным образом повлияет на результат.<br>
# Поэтому оставляем значения отсутствующими и строим аналитику по этому столбцу по имеющимся у нас значениям.<br>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Верно, пропуск может означать, что объявление не снято с продажи.</div>

# %% [markdown]
# ### Вывод:

# %% [markdown]
# Заполнены отсутствующие значения в следующих колонках:<br>
# * 'ceiling_height' -- пропущенных значений 38.73%, заполняем медианами по секторам в зависимости от площади квартиры:
#     - Медиана по 1 сектору с площадью от 0 до 100 кв.м. - 2.6;
#     - Медиана по 2 сектору с площадью от 100 до 200 кв.м. - 3.0;
#     - Медиана по 3 сектору с площадью от 200 до 300 кв.м. - 3.33;
#     - Медиана по 4 сектору с площадью от 300 до 400 кв.м. - 3.32;
#     - Медиана по 5 сектору с площадью от 400 до 500 кв.м. - 3.175;
#     - Медиана по 6 сектору с площадью от 500 до 600 кв.м. - 3.45.
# * 'floors_total' -- пропущенных значений 0.36%, по предположению, что люди не указали последний этаж, потому что их этаж последний, в пустые значения колонки проставлены значения колонкни 'floor';
# * 'locality_name' -- пропущеных значений 0.21%, методика замена данных будет очень сложна, а их удаление не повлияет на ход исследования, строки удалены;
# * 'cityCenters_nearest' -- в колонке отсутствуют значения в местах, где нет центра города, соответственно заменяем отсутствующие значения на 0;
# * 'days_exposition' -- оставляем значения отсутствующими и строим аналитику по этому столбцу по имеющимся у нас значениям.
#
# Скорректированные значения:
# * 'ceiling_height' -- квартиры с высотой потолка более 6 метров имеют абсолютно типичное распределение площадей для квартир из первого сектора от 0 до 100 кв.м., заменяем медианой высоты потолка по 1 сектору;
# * 'living_area'-- пропуски заменили средним отношением жилой площади к общей площади;
# * 'kitchen_area' -- пропуски заменили средним отношением площади кухни к общей площади;
# * 'last_price' -- удаляли одну строку с экстремальным значением.
#
# Измененные типы в колонках:
# * 'floors_total' -- изменяем тип колонки на int64;
# * 'first_day_exposition' -- изменяем тип колонки на datetime64 с форматом 'YYYY-MM-DD';
# * 'days_exposition' -- изменяем тип колонки на int64;
# * 'cityCenters_nearest' -- изменяем тип колонки на int64.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Данные обработаны и преведены к нужным типам верно.</div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу:

# %% [markdown]
# Проверяем типы колонок:

# %%
data.dtypes
# Out:
# last_price                     float64
# rooms                            int64
# total_area                     float64
# living_area                    float64
# kitchen_area                   float64
# ceiling_height                 float64
# floors_total                     int64
# floor                            int64
# locality_name                   object
# cityCenters_nearest              int64
# first_day_exposition    datetime64[ns]
# days_exposition                float64
# dtype: object

# %% [markdown]
# ### Расчет цены квадратного метра:

# %%
data['1m2_price'] = (data['last_price'] / data['total_area']).astype(int)
data.head(5)
# Out:
#    last_price  rooms  total_area  living_area  kitchen_area  ceiling_height  \
# 0  13000000.0      3       108.0         51.0          25.0            2.70
# 1   3350000.0      1        40.4         18.6          11.0            2.60
# 2   5196000.0      2        56.0         34.3           8.3            2.60
# 3  64900000.0      3       159.0         91.2          27.7            3.00
# 4  10000000.0      2       100.0         32.0          41.0            3.03
#
#    floors_total  floor    locality_name  cityCenters_nearest  \
# 0            16      8  санкт-петербург                16028
# 1            11      1   посёлок шушары                18603
# 2             5      4  санкт-петербург                13933
# 3            14      9  санкт-петербург                 6800
# 4            14     13  санкт-петербург                 8098
#
#   first_day_exposition  days_exposition  1m2_price
# 0           2019-03-07              NaN     120370
# ...

# %% [markdown]
# ### Добавление колонки с днем недели, месяцем и годом публикации объявления:

# %%
data['weekday_exposition'] = data['first_day_exposition'].dt.weekday
data['month_exposition'] = data['first_day_exposition'].dt.month
data['year_exposition'] = data['first_day_exposition'].dt.year
data.head(5)
# Out:
#    last_price  rooms  total_area  living_area  kitchen_area  ceiling_height  \
# 0  13000000.0      3       108.0         51.0          25.0            2.70
# 1   3350000.0      1        40.4         18.6          11.0            2.60
# 2   5196000.0      2        56.0         34.3           8.3            2.60
# 3  64900000.0      3       159.0         91.2          27.7            3.00
# 4  10000000.0      2       100.0         32.0          41.0            3.03
#
#    floors_total  floor    locality_name  cityCenters_nearest  \
# 0            16      8  санкт-петербург                16028
# 1            11      1   посёлок шушары                18603
# 2             5      4  санкт-петербург                13933
# 3            14      9  санкт-петербург                 6800
# 4            14     13  санкт-петербург                 8098
#
#   first_day_exposition  days_exposition  1m2_price  weekday_exposition  \
# ...

# %% [markdown]
# ### Категоризация этажа квартиры (первый, последний, другой):

# %%
def floor_category(row):
    if row['floor'] == row['floors_total']:
        return 'Последний'
    if row['floor'] == 1:
        return 'Первый'
    return 'Другой'

data['floor_category'] = data.apply(floor_category, axis=1) 

data['floor_category'].value_counts()
# Out:
# Другой       17326
# Последний     3439
# Первый        2884
# Name: floor_category, dtype: int64

# %% [markdown]
# Изменение типа колонки на тип "категория"

# %%
data['floor_category'] = data['floor_category'].astype('category').cat.codes

# %% [markdown]
# ### Расчет соотношения жилой и общей площади, площади кухни к общей:

# %%
data['ratio_living_to_total'] = (data['living_area'] / data['total_area']).round(2)
data['ratio_kitchen_to_total'] = (data['kitchen_area'] / data['total_area']).round(2)
data.head()
# Out:
#    last_price  rooms  total_area  living_area  kitchen_area  ceiling_height  \
# 0  13000000.0      3       108.0         51.0          25.0            2.70
# 1   3350000.0      1        40.4         18.6          11.0            2.60
# 2   5196000.0      2        56.0         34.3           8.3            2.60
# 3  64900000.0      3       159.0         91.2          27.7            3.00
# 4  10000000.0      2       100.0         32.0          41.0            3.03
#
#    floors_total  floor    locality_name  cityCenters_nearest  \
# 0            16      8  санкт-петербург                16028
# 1            11      1   посёлок шушары                18603
# 2             5      4  санкт-петербург                13933
# 3            14      9  санкт-петербург                 6800
# 4            14     13  санкт-петербург                 8098
#
#   first_day_exposition  days_exposition  1m2_price  weekday_exposition  \
# ...

# %% [markdown]
# ###  Вывод:

# %% [markdown]
# В таблицу добавлено расчеты следующих параметров:
# * цена квадратного метра;
# * день недели, месяц и год публикации объявления;
# * этаж квартиры; варианты — первый, последний, другой;
# * соотношение жилой и общей площади, отношение площади кухни к общей.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Здесь все расчитано и добавлено правильно: цена кв. метра, день недели, месяц и год публикации, соотношение площадей.
#
# Молодец, что провел категоризацию этажности через функцию.
#
# Хорошая практика - не называть столбцы, датафреймы переменные именами, которые начинаются с цифры.</div>

# %% [markdown]
# ## Исследовательский анализ данных:

# %% [markdown]
# ### Изучение параметров: площадь, цена, число комнат, высота потолков. Построение гистограмм для каждого параметра:

# %% [markdown]
# #### Изучение параметра - площадь:

# %% [markdown]
# Посмотрим на распределение значений в колонке и посчитаем медиану:

# %%
print('Медианное значение', data['total_area'].median().round(2))
data['total_area'].describe()
# Out:
# Медианное значение 52.0
# count    23649.000000
# mean        60.327011
# std         35.661158
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Чтобы ограничить разрядность после запятой, можно задать формат вывода:
#
# `df['last_price'].describe().apply('{0:.2f}'.format)`</div>

# %% [markdown]
# Построим гистограмму данного параметра:

# %%
data['total_area'].hist(bins=200, figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По гистограмме видим нормальное распределение значений с характерными пиками в районе 30кв.м., 45кв.м., 55кв.м. и далее.<br>
# Эти пики объясняются квартирностью то есть пик в районе 30кв.м. это однокомнатные квартиры, 45кв.м. это двухкомнатные квартиры и т.д.<br>
# После 200кв.м. значения не представляют ценности для исследования, уберем их из нашего графика.

# %%
data['total_area'].hist(bins=200, range=(0,200), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Изучение параметра - цена:
# Посмотрим на распределение значений в колонке и посчитаем медиану:

# %%
print('Медианное значение', data['last_price'].median().round(2))
data['last_price'].describe()
# Out:
# Медианное значение 4650000.0
# count    2.364900e+04
# mean     6.541403e+06
# std      1.089655e+07
# min      4.300000e+05
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.799000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Построим гистограмму данного параметра:

# %%
data['last_price'].hist(bins=500, figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# На графике видим значения более 100млн.руб., более 200 млн.руб. уже не видим, поэтому ограничим наш график 200млн.руб.

# %%
data['last_price'].hist(bins=500, range=(0,20000000), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# На графике появилось много пик, проанализируем экстремумы, что бы понять их характер:

# %%
data['last_price'].value_counts().head(10)
# Out:
# 4500000.0    342
# 3500000.0    289
# 4000000.0    260
# 4300000.0    260
# 4200000.0    258
# 3600000.0    257
# 3300000.0    244
# 3800000.0    240
# 3200000.0    238
# 3700000.0    233
# Name: last_price, dtype: int64

# %% [markdown]
# Видим что экстремумы вызваны тем, что люди при установлении цены квартиры округляли цены, соответственно для корректного отображения графика его нужно разбить на более крупные отрезки:

# %%
data['last_price'].hist(bins=100, range=(0,20000000), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По гистограмме видим нормальное распределение, без аномалий.

# %% [markdown]
# #### Изучение параметра - комнаты:
# Посмотрим на распределение значений в колонке и посчитаем медиану:

# %%
print('Медианное значение', data['rooms'].median().round(2))
data['rooms'].describe()
# Out:
# Медианное значение 2.0
# count    23649.000000
# mean         2.070109
# std          1.078643
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Построим гистограмму данного параметра:

# %%
data['rooms'].hist(bins=15, range=(0,15), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По гистограмме видим нормальное распределение, без аномалий.
# Медианное значение 2.0

# %% [markdown]
# #### Изучение параметра - высота потолка:
# Посмотрим на распределение значений в колонке и посчитаем медиану:

# %%
print('Медианное значение', data['ceiling_height'].median().round(2))
data['ceiling_height'].describe()
# Out:
# Медианное значение 2.6
# count    23649.000000
# mean         2.688593
# std          0.234434
# min          1.000000
# 25%          2.600000
# 50%          2.600000
# 75%          2.700000
# max          6.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Построим гистограмму данного параметра:

# %%
data['ceiling_height'].hist(bins=6, range=(0,6), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По гистограмме видим нормальное распределение, без аномалий.

# %% [markdown]
# #### Вывод:

# %% [markdown]
# **Вывод по параметру - площадь:**<br>
# У параметра нормальное распределение значений с характерными пиками в районе 30кв.м., 45кв.м., 55кв.м. и далее.<br>
# Эти пики объясняются квартирностью то есть пик в районе 30кв.м. это однокомнатные квартиры, 45кв.м. это двухкомнатные квартиры и т.д.<br>
#
# **Вывод по параметру - цена:**<br>
# У параметра видим нормальное распределение, без аномалий, с наличием пик связанных с тем, что люди при установлении цены квартиры округляли цены.<br>
#
# **Вывод по параметру - комнаты:**<br>
# По гистограмме видим нормальное распределение, без аномалий.<br>
# Медианное значение 2.0
#
# **Вывод по параметру - высота потолка:**<br>
# По гистограмме видим нормальное распределение, без аномалий.<br>
# Медианное значение 2.6

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Гистограммы отображены и прокомментированы правильно.</div>

# %% [markdown]
# ### Изучение время продажи квартиры. Построение гистограммы. Расчет среднего и медианы. Анализ процесса продажи:

# %% [markdown]
# #### Изучение время продажи квартиры:
# Посмотрим на распределение значений в колонке и посчитаем медиану:

# %%
print('Пропущенные значения: {:.2%}'.format(data['first_day_exposition'][data['days_exposition'].isnull()].count() / len(data)))
print(data['days_exposition'].describe())
# Out:
# Пропущенные значения: 13.45%
# count    20469.000000
# mean       180.761640
# std        219.779967
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Необходимо убрать 13% строк из расчета, так как если их заменять средним или медианным значением, то мы получим выбивающиеся значения, а если мы будем распределять эти значения равномерно то график не изменится а мы просто потратим время, более того 20 тысяч строк достаточно для проведения анализа.

# %%
exposition_data = data[data['days_exposition'].notnull()]
exposition_data = exposition_data.astype({'days_exposition': 'int64'})
print('Тип колонки days_exposition:', exposition_data['days_exposition'].dtypes)
exposition_data.head(5)
# Out:
# Тип колонки days_exposition: int64
#    last_price  rooms  total_area  living_area  kitchen_area  ceiling_height  \
# 1   3350000.0      1        40.4         18.6          11.0            2.60
# 2   5196000.0      2        56.0         34.3           8.3            2.60
# 3  64900000.0      3       159.0         91.2          27.7            3.00
# 4  10000000.0      2       100.0         32.0          41.0            3.03
# 5   2890000.0      1        30.4         14.4           9.1            2.60
#
#    floors_total  floor              locality_name  cityCenters_nearest  \
# 1            11      1             посёлок шушары                18603
# 2             5      4            санкт-петербург                13933
# 3            14      9            санкт-петербург                 6800
# 4            14     13            санкт-петербург                 8098
# 5            12      5  городской посёлок янино-1                    0
#
# ...

# %% [markdown]
# #### Построение гистограммы:

# %% [markdown]
# Посмотрим на распределение данных по гистограмме:

# %%
exposition_data['days_exposition'].hist(bins=500, figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По графику видно:количество дней более 500 встречается крайне редко - отбрасываем эту часть:

# %%
exposition_data['days_exposition'].hist(bins=500, range=(0,500), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Найдем выбивающиеся значения которых более 200:

# %%
exposition_data['days_exposition'].value_counts().head(10)
# Out:
# 45    879
# 60    538
# 7     234
# 30    208
# 90    203
# 4     174
# 3     158
# 5     152
# 14    148
# 9     142
# Name: days_exposition, dtype: int64

# %% [markdown]
# Как мы видим наибольшее количество объявлений было закрыто на 7, 30, 45, 60, 90 что говорит о скорее всего об их автоматическом закрытии, удалим эти обявления, так как не возможно корректно определить как заменять значения(невозможно обосновать было то или объявление закрыто автоматически или состоялась продажа) и построим график.

# %%
exposition_data_no_auto = exposition_data.query('days_exposition != 45 and days_exposition != 30 and days_exposition != 7 and days_exposition != 60 and days_exposition != 90')
exposition_data_no_auto['days_exposition'].hist(bins=500, range=(0,500), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По графику видим большое количество закрытия объявлений выведем этим значения:

# %%
exposition_data_no_auto['days_exposition'].value_counts().head(10)
# Out:
# 4     174
# 3     158
# 5     152
# 14    148
# 9     142
# 20    139
# 44    138
# 8     138
# 11    135
# 18    129
# Name: days_exposition, dtype: int64

# %% [markdown]
# Первые три максимальные значения это закрытие объявлений на 3, 4, 5 день, что скорее всего не продажа, а человек либо передумал, либо пересоздал объявление либо еще какие-то обстоятельства, при интерпретации графиков это обязательно нужно учитывать.

# %% [markdown]
# Посчитаем среднее и медианное значение количества дней объявлений без автоматического закрытия:

# %%
print('Медианное значение:', exposition_data_no_auto['days_exposition'].median().round(1))
print('Среднее значение:',exposition_data_no_auto['days_exposition'].mean().round(1))
exposition_data_no_auto['days_exposition'].describe()
# Out:
# Медианное значение: 114.0
# Среднее значение: 195.7
# count    18407.000000
# mean       195.687890
# std        226.834183
# min          1.000000
# 25%         44.000000
# 50%        114.000000
# 75%        258.500000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# #### Вывод:

# %% [markdown]
# Медианное время продажи квартиры: 114.0
# Среднее время продажи квартиры: 195.7
#
# Анализ процесса продажи:
# Первые 5 дней рассматриваем как техническое закрытие объявления;<br>
# Первый квартиль - 44 дня рассматриваем как сверхбыстрая продажа;<br>
# Внутри ящика - от 44 дней до 258 дней нормальная продажа;<br>
# После 3 квартиля - от 258 дней необычно долгие продажи.<br>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Отличный и подробный анализ срока размещения объявлений! 👍</div>

# %% [markdown]
# ### Изучение влияния факторов на стоимость квартиры. Изучение зависимости цены от площади, числа комнат, удалённости от центра. Изучение зависимости цены от того, на каком этаже расположена квартира.  Изучение зависимости от даты размещения: дня недели, месяца и года:

# %% [markdown]
# #### Зависимость цены от площади:

# %%
data.plot(x='last_price', y='total_area', kind='scatter', xlim=(0,25000000), ylim=(0,200), figsize=(20,5), alpha=0.3) 
print('Коэффициент корреляции:', data['last_price'].corr(data['total_area']).round(2))
# Out:
# Коэффициент корреляции: 0.65

# %% [markdown]
# #### Зависимость цены от количества комнат:

# %%
data.plot(x='last_price', y='rooms', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,40000000), ylim=(0,10)) 
print('Коэффициент корреляции:', data['last_price'].corr(data['rooms']).round(2))
# Out:
# Коэффициент корреляции: 0.36

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# По таким графикам оценить зависимость сложно. Имеет смысл сравнить медианные цены квартир (а лучше кв. метра) с разным количеством комнат.</div>

# %% [markdown]
# <p>
# <div class="alert-info">
# <b>Хм очень крутая идея:)</b>

# %%
average_price_m2 = []
floor = []

for i in range(1,9):
    average_price_m2.append(int(data[data['floor']== i]['last_price'].sum() / data[data['floor']== i]['total_area'].sum()))
    floor.append(i)

pd.DataFrame(average_price_m2, index =floor, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера V2 ⚠️</b>
#
# Я имел в виду скорее такую визуализацию.👇
#
# По ней видно, что квадратный метр в однушке самый дорогой.
#
# У тебя же посчитана стоимость квадратного метра для каждого объявления, поэтому дополнительные списки и датафреймы для группировки и визуализации создавать не целесообразно.</div>

# %%
#Код ревьюера
import matplotlib.pyplot as plt

data.query('0 < rooms < 6').groupby('rooms')['1m2_price'].median()\
    .plot(kind = 'bar', title = 'Медианная цена кв. м в зависимости от количества комнат')
plt.show()

# %% [markdown]
# #### Зависимость цены от удаленности от центра:

# %%
data[data['cityCenters_nearest'] != 0].plot(x='last_price', y='cityCenters_nearest', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,15000000), ylim=(0,40000))
print('Коэффициент корреляции:', data['last_price'].corr(data['cityCenters_nearest'][data['cityCenters_nearest'] != 0]).round(2))
# Out:
# Коэффициент корреляции: -0.21

# %% [markdown]
# #### Зависимость цены от этажа:

# %%
data.plot(x='last_price', y='floor_category', kind='scatter', figsize=(20,5), alpha=0.3, xlim=(0,15000000))
print('Коэффициент корреляции:', data['last_price'].corr(data['floor_category']).round(2))
# Out:
# Коэффициент корреляции: 0.0

# %%
average_price_m2 = []
floor_category = []

for i in range(0,3):
    average_price_m2.append(int(data[data['floor_category']== i]['last_price'].sum() / data[data['floor_category']== i]['total_area'].sum()))
    floor_category.append(i)

pd.DataFrame(average_price_m2, index =floor_category, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Зависимость цены от даты размещения: дня недели:

# %%
data.plot(x='last_price', y='weekday_exposition', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,15000000), ylim=(0,7))
print('Коэффициент корреляции:', data['last_price'].corr(data['weekday_exposition']).round(2))
# Out:
# Коэффициент корреляции: 0.0

# %%
average_price_m2 = []
weekday_exposition = ['Понедельник', 'Вторник', 'Среда', 'Четверг', 'Пятница', 'Суббота', 'Воскресенье']

for i in range(0,7):
    average_price_m2.append(int(data[data['weekday_exposition']== i]['last_price'].sum() / data[data['weekday_exposition']== i]['total_area'].sum()))


pd.DataFrame(average_price_m2, index =weekday_exposition, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Зависимость цены от даты размещения: месяца:

# %%
data.plot(x='last_price', y='month_exposition', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,15000000), ylim=(0,13))
print('Коэффициент корреляции:', data['last_price'].corr(data['month_exposition']).round(2))
# Out:
# Коэффициент корреляции: 0.0

# %%
average_price_m2 = []
month_exposition = []

for i in range(1,13):
    average_price_m2.append(int(data[data['month_exposition']== i]['last_price'].sum() / data[data['month_exposition']== i]['total_area'].sum()))
    month_exposition.append(i)

pd.DataFrame(average_price_m2, index =month_exposition, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Зависимость цены от даты размещения: года:

# %%
data.plot(x='last_price', y='year_exposition', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,100000000), ylim=(2013,2020))
print('Коэффициент корреляции:', data['last_price'].corr(data['year_exposition']).round(2))
# Out:
# Коэффициент корреляции: -0.04

# %%
average_price_m2 = []
year_exposition = []

for i in range(2014, 2020):
    average_price_m2.append(int(data[data['year_exposition']== i]['last_price'].sum() / data[data['year_exposition']== i]['total_area'].sum()))
    year_exposition.append(i)

pd.DataFrame(average_price_m2, index =year_exposition, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Последние четыре графика не очень информативны. Имеет смысл сравнивать медианные цены квартир (или квадратного метра) в разных временных интервалах, а также разных категорий этажей.</div>

# %% [markdown]
# <p>
# <div class="alert-info">
# <b>Сделано!</b>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Так стало гораздо наглядней.</div>

# %% [markdown]
# #### Вывод всех корреляции:

# %%
display(data[['last_price', 'year_exposition', 'month_exposition', 'weekday_exposition', 'cityCenters_nearest', 'rooms', 'total_area']].corr().round(2)['last_price'].sort_values(ascending=False))
print('Коэффициент корреляции cityCenters_nearest:', data['last_price'].corr(data['cityCenters_nearest'][data['cityCenters_nearest'] != 0]).round(2))
# Out:
# last_price             1.00
# total_area             0.65
# rooms                  0.36
# month_exposition       0.00
# weekday_exposition     0.00
# year_exposition       -0.04
# cityCenters_nearest   -0.05
# Name: last_price, dtype: float64
# Коэффициент корреляции cityCenters_nearest: -0.21

# %% [markdown]
# #### Вывод:

# %% [markdown]
# Из следующих факторов:
# - last_price;
# - year_exposition;
# - month_exposition;
# - weekday_exposition;
# - rooms;
# - total_area;
# - cityCenters_nearest;<br>
#
# на стоимость квартиры влияют:<br>
# * Чем больше площадь квартиры тем выше цена - коэффициент корреляции 0.65;
# * Чем дальше от центра находится квартира тем меньше цена - коэффициент корреляции (-0.21);
# * Стоимость квадратного метра падает с 2014 года до 2018 года и корректируется в 2019 году;
# * Выраженный тренд зависимости от месяца публикации объявления отсутствует;
# * В субботу публикуют объявления с более высокой стоимостью квартиры относительно всех остальных дней недели;
# * Стоимость квадратного метра на первом и последнем этаже выше чем в середине здания;
# * Чем больше комнат в квартире тем выше стоимость квадратного метра - коэффициент корреляции 0.36.
#
# Остальные параметры не влияют на стоимость квартиры.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Попробуй рассмотреть медианные цены, как я написал выше - возможно выводы изменятся.</div>

# %% [markdown]
# <p>
# <div class="alert-info">
# <b>Сделано!</b>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Теперь выводы стали лучше. Странно только что у тебя получилось что "Стоимость квадратного метра на первом и последнем этаже выше чем в середине здания". Обычно наоборот.</div>

# %% [markdown]
# ### Отбор 10 населённых пунктов с наибольшим числом объявлений. Расчет средней цены квадратного метра в этих населённых пунктах. Выделение населённых пунктов с самой высокой и низкой стоимостью жилья.

# %% [markdown]
# #### Вывод списка из 10 населённых пунктов с наибольшим числом объявлений:

# %%
top_10_locality = data['locality_name'].value_counts().head(10).index.tolist()

# %% [markdown]
# #### Расчет средней цены квадратного метра в этих населённых пунктах:

# %% [markdown]
# Создаем пустой список с ценой на квадратный метр и производим расчет квадратного метра:

# %%
average_meter_price = []
for item in top_10_locality:
    average_meter_price.append(data['last_price'][data['locality_name'] == item].sum() / data['total_area'][data['locality_name'] == item].sum())
average_meter_price_df = pd.DataFrame(average_meter_price, index =top_10_locality, columns =['average_meter_price'])
average_meter_price_df.round(2)
# Out:
#                    average_meter_price
# санкт-петербург              124527.94
# посёлок мурино                83203.31
# посёлок шушары                76328.22
# всеволожск                    67635.13
# пушкин                       105097.36
# колпино                       74467.62
# посёлок парголово             87110.87
# гатчина                       68475.38
# деревня кудрово               90916.90
# выборг                        57898.14

# %% [markdown]
# #### Построение гистограммы:

# %%
average_meter_price_df.sort_values(by='average_meter_price',ascending=False).plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Вывод:
# Самый дорогой квадратный метр ожидаемо в Санкт-Петербурге, а самый дешевый в Выборге.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Этот шаг работы выполнен верно.</div>

# %% [markdown]
# ### Определение центральной зоны Санкт-Петербурга:

# %% [markdown]
# #### Создание выборки по городу Санкт-Петербург и расчет отдаленности от центра города в километрах:

# %%
spb_data = data[data['locality_name'] == 'санкт-петербург']
spb_data.loc[:, 'cityCenters_nearest_km'] = (spb_data['cityCenters_nearest'] / 1000).astype(int)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Избавиться от предупреждений питона можно так:
#
# `import warnings
#  warnings.filterwarnings('ignore')`</div>

# %% [markdown]
# #### Построение графика зависимости цены от от удаленности квартиры от центра:

# %%
spb_data.plot(x='last_price', y='cityCenters_nearest_km', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,30000000), ylim=(0,26))
# Out:
# <AxesSubplot:xlabel='last_price', ylabel='cityCenters_nearest_km'>

# %%
average_price_m2 = []
cityCenters_nearest_km = []

for i in range(0, 25):
    average_price_m2.append(int(spb_data[spb_data['cityCenters_nearest_km']== i]['last_price'].sum() / spb_data[spb_data['cityCenters_nearest_km']== i]['total_area'].sum()))
    cityCenters_nearest_km.append(i)

pd.DataFrame(average_price_m2, index =cityCenters_nearest_km, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Расчет средней цены для каждого километра:

# %%
spb_data_av_price_km = spb_data.pivot_table(index='cityCenters_nearest_km', values=['last_price','total_area'], aggfunc='sum').reset_index()
spb_data_av_price_km['m2_price'] = (spb_data_av_price_km['last_price'] / spb_data_av_price_km['total_area']).astype(int)
display(spb_data_av_price_km.head(5))
# Out:
#    cityCenters_nearest_km    last_price  total_area  m2_price
# 0                       0  2.973330e+09    15054.82    197500
# 1                       1  4.524204e+09    24739.10    182876
# 2                       2  4.962137e+09    30348.94    163502
# 3                       3  7.067773e+09    48154.42    146773
# 4                       4  1.236425e+10    87220.66    141758

# %% [markdown]
# #### Построение графика зависимости стоимости квадратного метра от удаленности квартиры от центра:

# %%
spb_data_av_price_km.plot(x='cityCenters_nearest_km', y='m2_price', kind='line', figsize=(20,5), alpha=1,  ylim=(0,300000), xlim=(0,26))
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest_km'>

# %% [markdown]
# #### Вывод:

# %% [markdown]
# Цена квадратного метра остается высокой вплоть до 7 км. включительно, далее идет резкий скачок по уменьшению стоимости квадратного метра, что говорит о том, что именно эта удаленность психологически воспринимается как не центр.<br>
# За центр принимаем удаленность до 7 км включительно.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Центр города определен верно.</div>

# %% [markdown]
# ### Анализ сегмента квартир в центре. Изучение параметров: площадь, цена, число комнат, высота потолков. Изучение факторов влияющих на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Анализ отличий от общих выводов по всей базе:

# %% [markdown]
# Создаем два датафрейма для данных в центре и данных не в центре:

# %%
spb_data_centr = spb_data[['ceiling_height', 'last_price', 'rooms', 'total_area', 'floor', 'cityCenters_nearest_km', 'first_day_exposition', 'weekday_exposition', 'month_exposition', 'year_exposition']][spb_data['cityCenters_nearest_km'] <= 7]
spb_data_all = spb_data[['ceiling_height', 'last_price', 'rooms', 'total_area', 'floor', 'cityCenters_nearest_km', 'first_day_exposition', 'weekday_exposition', 'month_exposition', 'year_exposition']][spb_data['cityCenters_nearest_km'] > 7]

# %% [markdown]
# Проверим корреляцию параметров квартир в центре и по всей территории:

# %%
print('Корреляция параметров в центре:')
display(spb_data_centr[['ceiling_height', 'last_price', 'rooms', 'total_area', 'floor']].corr().round(2)['last_price'].sort_values(ascending=False))
print('Корреляция параметров на всей территории:')
display(spb_data_all[['ceiling_height', 'last_price', 'rooms', 'total_area']].corr().round(2)['last_price'].sort_values(ascending=False))
# Out:
# Корреляция параметров в центре:
# last_price        1.00
# total_area        0.64
# rooms             0.34
# ceiling_height    0.25
# floor             0.12
# Name: last_price, dtype: float64
# Корреляция параметров на всей территории:
# last_price        1.00
# total_area        0.84
# rooms             0.52
# ceiling_height    0.48
# Name: last_price, dtype: float64

# %% [markdown]
# Видим что параметры оказывают большее влияние на цену на всей территории города, нежели в центре.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Коэффициенты корреляций по общей базе вроде бы выше...</div>

# %% [markdown]
# <p>
# <div class="alert-info">
# <b>Согласен, засмотрелся куда то не туда)</b>

# %% [markdown]
# #### Изучение параметра - площадь:

# %%
print('Медианное значение', spb_data_centr['total_area'].median().round(2))
spb_data_centr['total_area'].describe()
# Out:
# Медианное значение 77.3
# count    3773.000000
# mean       92.269891
# std        60.723056
# min        12.000000
# 25%        56.000000
# 50%        77.300000
# 75%       108.700000
# max       900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Построим гистограмму данного параметра:

# %%
spb_data_centr['total_area'].hist(bins=200, range=(0,300), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По гистограмме видим нормальное распределение значений.

# %% [markdown]
# Выведем график по всей территории:

# %%
spb_data_all['total_area'].hist(bins=200, range=(0,300), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Медианное значение по квартирам по всей территории 52кв.м. а по квартирам в центре 77кв.м.
# Это мы и видим при сравнении графиков в центре меньше квартир с площадью от 30кв.м. до 45кв.м., за то гораздо больше квартир от 50 до 100. Так же видим что меньше влияет квартирность (меньше пик на определенных квадратных метрах), что вполне логично, так как в центре здания старше и не типовые как на окраинах.

# %% [markdown]
# #### Изучение параметра - цена:
# Посмотрим на распределение значений в колонке и посчитаем медиану:

# %%
print('Медианное значение', spb_data_centr['last_price'].median().round(2))
spb_data_centr['last_price'].describe()
# Out:
# Медианное значение 9000000.0
# count    3.773000e+03
# mean     1.474520e+07
# std      2.463546e+07
# min      1.600000e+06
# 25%      6.550000e+06
# 50%      9.000000e+06
# 75%      1.420000e+07
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Построим гистограмму данного параметра:

# %%
spb_data_centr['last_price'].hist(bins=100, range=(0,30000000), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По гистограмме видим нормальное распределение, без аномалий.
# Выведем график по всей территории:

# %%
print('Медианное значение', spb_data_all['last_price'].median().round(2))
spb_data_all['last_price'].hist(bins=100, range=(0,20000000), figsize=(20,5))
# Out:
# Медианное значение 4950000.0
# <AxesSubplot:>

# %% [markdown]
# При сравнении графиков видим смещение пика цены квартиры в центре вправо, смещение медианы с 4.95млн.руб до 9млн.руб..

# %% [markdown]
# #### Изучение параметра - комнаты:
# Посмотрим на распределение значений в колонке и посчитаем медиану:

# %%
print('Медианное значение', spb_data_centr['rooms'].median().round(2))
spb_data_centr['rooms'].describe()
# Out:
# Медианное значение 3.0
# count    3773.000000
# mean        2.805195
# std         1.457403
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max        19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Построим гистограмму данного параметра:

# %%
spb_data_centr['rooms'].hist(bins=15, range=(0,15), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По гистограмме видим нормальное распределение, без аномалий.<br>
# Построим гистограмму по всей территории:

# %%
spb_data_all['rooms'].hist(bins=15, range=(0,15), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# В центральной территории видим пик на значении 4 комнат, а по всей территории пик приходится на 2 комнаты.

# %% [markdown]
# #### Изучение параметра - высота потолка:
# Посмотрим на распределение значений в колонке и посчитаем медиану:

# %%
print('Медианное значение', spb_data_centr['ceiling_height'].median().round(2))
spb_data_centr['ceiling_height'].describe()
# Out:
# Медианное значение 3.0
# count    3773.000000
# mean        2.953334
# std         0.372567
# min         2.000000
# 25%         2.600000
# 50%         3.000000
# 75%         3.150000
# max         6.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Построим гистограмму данного параметра:

# %%
spb_data_centr['ceiling_height'].hist(bins=6, range=(0,6), figsize=(20,5))
spb_data_centr['ceiling_height'].describe()
# Out:
# count    3773.000000
# mean        2.953334
# std         0.372567
# min         2.000000
# 25%         2.600000
# 50%         3.000000
# 75%         3.150000
# max         6.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# По гистограмме видим нормальное распределение, без аномалий. Построим гистограмму по всей территории:

# %%
spb_data_all['ceiling_height'].hist(bins=6, range=(0,6), figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# В центральной территории видим пик на значении высоты потолка от 3м. до 4м., а по всей территории пик приходится на высоту потолка от 2м. до 3м..

# %% [markdown]
# #### Зависимость цены от количества комнат:

# %%
spb_data_centr.plot(x='last_price', y='rooms', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,40000000), ylim=(0,10)) 
print('Коэффициент корреляции:', spb_data_centr['last_price'].corr(spb_data_centr['rooms']).round(2))
# Out:
# Коэффициент корреляции: 0.34

# %%
average_price_m2 = []
rooms = []

for i in range(0, 8):
    average_price_m2.append(int(spb_data_centr[spb_data_centr['rooms']== i]['last_price'].sum() / spb_data_centr[spb_data_centr['rooms']== i]['total_area'].sum()))
    rooms.append(i)

pd.DataFrame(average_price_m2, index =rooms, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
spb_data_all.plot(x='last_price', y='rooms', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,40000000), ylim=(0,10)) 
print('Коэффициент корреляции:', spb_data_all['last_price'].corr(spb_data_all['rooms']).round(2))
# Out:
# Коэффициент корреляции: 0.52

# %%
average_price_m2 = []
rooms = []

for i in range(0, 8):
    average_price_m2.append(int(spb_data_all[spb_data_all['rooms']== i]['last_price'].sum() / spb_data_all[spb_data_all['rooms']== i]['total_area'].sum()))
    rooms.append(i)

pd.DataFrame(average_price_m2, index =rooms, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Стоимость квартиры зависит от количества комнат для квартир в центре (Коэффициент корреляции: 0.34) сильно меньше, чем по всей территоррии (Коэффициент корреляции: 0.52).<br>
# Стоимость квадратного метра квартиры в центре с увеличением количества комнат увеличивается, когда стоимость квадратного метра квартиры по всей территории с увеличением количества комнат уменьшается.

# %% [markdown]
# #### Зависимость цены от этажа:

# %%
spb_data_centr.plot(x='last_price', y='floor', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,25000000), ylim=(0,30))
print('Коэффициент корреляции:', spb_data_centr['last_price'].corr(spb_data_centr['floor']).round(2))
# Out:
# Коэффициент корреляции: 0.12

# %%
average_price_m2 = []
floor = []

for i in range(1, 22):
    average_price_m2.append(int(spb_data_centr[spb_data_centr['floor']== i]['last_price'].sum() / spb_data_centr[spb_data_centr['floor']== i]['total_area'].sum()))
    floor.append(i)

pd.DataFrame(average_price_m2, index =floor, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
spb_data_all.plot(x='last_price', y='floor', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,25000000), ylim=(0,30))
print('Коэффициент корреляции:', spb_data_all['last_price'].corr(spb_data_all['floor']).round(2))
# Out:
# Коэффициент корреляции: 0.13

# %%
average_price_m2 = []
floor = []

for i in range(1, 22):
    average_price_m2.append(int(spb_data_all[spb_data_all['floor']== i]['last_price'].sum() / spb_data_all[spb_data_all['floor']== i]['total_area'].sum()))
    floor.append(i)

pd.DataFrame(average_price_m2, index =floor, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# В центре стоимость квадратного метра возрастает до 10 этажа, на 11 этаже резко падает и продолжает снижение до 18 этажа, и дальше снова переходит в рост, то есть имеет разнонаправленную динамику изменения цены квадратного метра при возрастании этажа, тогда как на значениях по всей территории видим возрастающий общий тренд при возрастании этажа.

# %% [markdown]
# #### Зависимость цены от даты размещения - дня недели:

# %%
spb_data_centr.plot(x='last_price', y='weekday_exposition', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,15000000), ylim=(0,7))
print('Коэффициент корреляции:', spb_data_centr['last_price'].corr(spb_data_centr['weekday_exposition']).round(2))
# Out:
# Коэффициент корреляции: 0.02

# %%
average_price_m2 = []
weekday_exposition = []

for i in range(0, 7):
    average_price_m2.append(int(spb_data_centr[spb_data_centr['weekday_exposition']== i]['last_price'].sum() / spb_data_centr[spb_data_centr['weekday_exposition']== i]['total_area'].sum()))
    weekday_exposition.append(i)

pd.DataFrame(average_price_m2, index =weekday_exposition, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
spb_data_all.plot(x='last_price', y='weekday_exposition', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,15000000), ylim=(0,7))
print('Коэффициент корреляции:', spb_data_all['last_price'].corr(spb_data_all['weekday_exposition']).round(2))
# Out:
# Коэффициент корреляции: -0.0

# %%
average_price_m2 = []
weekday_exposition = []

for i in range(0, 7):
    average_price_m2.append(int(spb_data_all[spb_data_all['weekday_exposition']== i]['last_price'].sum() / spb_data_all[spb_data_all['weekday_exposition']== i]['total_area'].sum()))
    weekday_exposition.append(i)

pd.DataFrame(average_price_m2, index =weekday_exposition, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Зависимость цены от дня недели публикации на всей территории и в центральной территории отсутствует, кроме одной интересной особенности в центре в субботу публикуют объявления со стоимостью квадратного метра сильно выше обычного.

# %% [markdown]
# #### Зависимость цены от даты размещения - месяца:

# %%
spb_data_centr.plot(x='last_price', y='month_exposition', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,15000000), ylim=(0,13))
print('Коэффициент корреляции:', spb_data_centr['last_price'].corr(spb_data_centr['month_exposition']).round(2))
# Out:
# Коэффициент корреляции: -0.0

# %%
average_price_m2 = []
month_exposition = []

for i in range(1, 13):
    average_price_m2.append(int(spb_data_centr[spb_data_centr['month_exposition']== i]['last_price'].sum() / spb_data_centr[spb_data_centr['month_exposition']== i]['total_area'].sum()))
    month_exposition.append(i)

pd.DataFrame(average_price_m2, index =month_exposition, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
spb_data_all.plot(x='last_price', y='month_exposition', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,15000000), ylim=(0,13))
print('Коэффициент корреляции:', spb_data_all['last_price'].corr(spb_data_all['month_exposition']).round(2))
# Out:
# Коэффициент корреляции: 0.01

# %%
average_price_m2 = []
month_exposition = []

for i in range(1, 13):
    average_price_m2.append(int(spb_data_all[spb_data_all['month_exposition']== i]['last_price'].sum() / spb_data_all[spb_data_all['month_exposition']== i]['total_area'].sum()))
    month_exposition.append(i)

pd.DataFrame(average_price_m2, index =month_exposition, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Интересное наблюдение, что цена квадратного метра квартир по всей территории немного колеблется, но не имеет выраженной динамики, тогда как цена квадратного метра квартир в центре имеет три выраженных месяца, где стоимость квадратного метра выше, чем в среднем по месяцам это апрель сентябрь и декабрь.

# %% [markdown]
# #### Зависимость цены от даты размещения - года:

# %%
spb_data_centr.plot(x='last_price', y='year_exposition', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,100000000), ylim=(2013,2020))
print('Коэффициент корреляции:', spb_data_centr['last_price'].corr(spb_data_centr['year_exposition']).round(2))
# Out:
# Коэффициент корреляции: -0.05

# %%
average_price_m2 = []
year_exposition = []

for i in range(2014, 2020):
    average_price_m2.append(int(spb_data_centr[spb_data_centr['year_exposition']== i]['last_price'].sum() / spb_data_centr[spb_data_centr['year_exposition']== i]['total_area'].sum()))
    year_exposition.append(i)

pd.DataFrame(average_price_m2, index =year_exposition, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
spb_data_all.plot(x='last_price', y='year_exposition', kind='scatter', figsize=(20,5), alpha=0.3,  xlim=(0,100000000), ylim=(2013,2020))
print('Коэффициент корреляции:', spb_data_all['last_price'].corr(spb_data_all['year_exposition']).round(2))
# Out:
# Коэффициент корреляции: 0.01

# %%
average_price_m2 = []
year_exposition = []

for i in range(2014, 2020):
    average_price_m2.append(int(spb_data_all[spb_data_all['year_exposition']== i]['last_price'].sum() / spb_data_all[spb_data_all['year_exposition']== i]['total_area'].sum()))
    year_exposition.append(i)

pd.DataFrame(average_price_m2, index =year_exposition, columns =['average_price_m2']).plot(kind='bar', figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Цена квадратного метра с 2014 года снижается до 2018 года, и возвращается в рост в 2019 года, а по всей территории цена квадратного метра снижается с 2014 года до 2016 года и переходит к восстановлению уже в 2017.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# На таких графиках зависимость цены от этажа, количества комнат и времени размещения оценить очень сложно. Нужно сравнить медианные цены.</div>

# %% [markdown]
# <p>
# <div class="alert-info">
# <b>Поправлено!</b>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Отлично!</div>

# %% [markdown]
# #### Вывод:

# %% [markdown]
# **По параметру площадь:**<br>
# В центральной территории меньше квартир с площадью от 30кв.м. до 45кв.м., за то гораздо больше квартир от 50кв.м. до 100кв.м.. <br>
# Так же видим, что меньше влияет квартирность (меньше пик на определенных квадратных метрах), что вполне логично, так как в центре здания старше и не типовые как на окраинах.
#
# **По параметру цена:**<br>
# Медианная цена квартиры в центральной территории 9млн.руб., по всей территории 4.95млн.руб.
#
# **По параметру комнаты:**<br>
# Распределение показывает, что в центральной территории квартиры имеют больше комнат - в частности в центральной территории наибольшее количество квартир с 4 комнатами, а по всей территории наибольшее количество квартир с 2 комнатами.
#
# **По параметру высота потолка:**<br>
# Распределение показывает, что в центральной территории квартиры имеют более высокие потолки - в частности в центральной территории наибольшее количество квартир с потолками от 3м. до 4м., а по всей территории наибольшее количество квартир с потолками от 2м. до 3м., а квартиры с потолками от 3м. до 4м. составляют малую часть выборки.
#
# **Зависимость цены квартиры от количества комнат:**<br>
# Стоимость квартиры зависит от количества комнат для квартир в центре (Коэффициент корреляции: 0.34) сильно меньше, чем по всей территоррии (Коэффициент корреляции: 0.52).<br>
# Стоимость квадратного метра квартиры в центре с увеличением количества комнат увеличивается, когда стоимость квадратного метра квартиры по всей территории с увеличением количества комнат уменьшается.
#
# **Зависимость цены квартиры от этажа:**<br>
# В центре стоимость квадратного метра возрастает до 10 этажа, на 11 этаже резко падает и продолжает снижение до 18 этажа, и дальше снова переходит в рост, то есть имеет разнонаправленную динамику изменения цены квадратного метра при возрастании этажа, тогда как на значениях по всей территории видим возрастающий общий тренд при возрастании этажа.
#
# **Зависимость цены квартиры от даты:**<br>
# Зависимость цены квадратного метра от дня недели публикации на всей территории и в центральной территории отсутствует, кроме одной интересной особенности в центре в субботу публикуют объявления со стоимостью квадратного метра сильно выше обычного.<br>
#
# Цена квадратного метра квартир по всей территории немного колеблется в зависимости от месяца, но не имеет выраженной динамики, тогда как цена квадратного метра квартир в центре имеет три выраженных месяца, где стоимость квадратного метра выше, чем в среднем по месяцам это апрель, сентябрь и декабрь.<br>
#
# Цена квадратного метра в центре с 2014 года снижается до 2018 года, и возвращается в рост в 2019 году, а по всей территории цена квадратного метра снижается с 2014 года до 2016 года и переходит к восстановлению уже в 2017.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# По комнатам, этажам и сроку размещения не согласен с выводами, нужно проанализировать медианные цены.</div>

# %% [markdown]
# <p>
# <div class="alert-info">
# <b>Поправлено!</b>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Выводы поправлены по результатам изучения новых графиков. Теперь все хорошо.</div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Вывод по пункту 1 - Загрузка данных и первый осмотр:**<br>
# **При первой загрузке данных обнаружили отсутствие значений в следующих колонках:**<br>
# - 'ceiling_height';
# - 'floors_total';
# - 'locality_name';
# - 'cityCenters_nearest';
# - 'days_exposition';
# - 'living_area';
# - 'kitchen_area'.
#
# **Значения нуждающиеся в дополнительном анализе и корректировке:**<br>
# - 'ceiling_height';
# - 'cityCenters_nearest';
# - 'last_price'.
#
# **Значении в которых необходимо заменить тип:**<br>
# - 'floors_total';
# - 'first_day_exposition';
# - 'days_exposition'.
#
# **Вывод по пункту 2 - предобработка данных:**<br>
# **Заполнены отсутствующие значения в следующих колонках:**<br>
# * 'ceiling_height' -- пропущенных значений 38.73%, заполняем медианами по секторам в зависимости от площади квартиры:
#     - Медиана по 1 сектору с площадью от 0 до 100 кв.м. - 2.6;
#     - Медиана по 2 сектору с площадью от 100 до 200 кв.м. - 3.0;
#     - Медиана по 3 сектору с площадью от 200 до 300 кв.м. - 3.33;
#     - Медиана по 4 сектору с площадью от 300 до 400 кв.м. - 3.32;
#     - Медиана по 5 сектору с площадью от 400 до 500 кв.м. - 3.175;
#     - Медиана по 6 сектору с площадью от 500 до 600 кв.м. - 3.45.
# * 'floors_total' -- пропущенных значений 0.36%, по предположению, что люди не указали последний этаж, потому что их этаж последний, в пустые значения колонки проставлены значения колонкни 'floor';
# * 'locality_name' -- пропущеных значений 0.21%, методика замена данных будет очень сложна, а их удаление не повлияет на ход исследования, строки удалены;
# * 'cityCenters_nearest' -- в колонке отсутствуют значения в местах, где нет центра города, соответственно заменяем отсутствующие значения на 0;
# * 'days_exposition' -- оставляем значения отсутствующими и строим аналитику по этому столбцу по имеющимся у нас значениям.
#
# **Скорректированные значения:**<br>
# * 'ceiling_height' -- квартиры с высотой потолка более 6 метров имеют абсолютно типичное распределение площадей для квартир из первого сектора от 0 до 100 кв.м., заменяем медианой высоты потолка по 1 сектору;
# * 'living_area'-- пропуски заменили средним отношением жилой площади к общей площади;
# * 'kitchen_area' -- пропуски заменили средним отношением площади кухни к общей площади;
# * 'last_price' -- удаляли одну строку с экстремальным значением.
#
# **Измененные типы в колонках:**<br>
# * 'floors_total' -- изменяем тип колонки на int64;
# * 'first_day_exposition' -- изменяем тип колонки на datetime64 с форматом 'YYYY-MM-DD';
# * 'days_exposition' -- изменяем тип колонки на int64;
# * 'cityCenters_nearest' -- изменяем тип колонки на int64.
#
# **Вывод по пункту 3 - Расчёты и добавление результатов в таблицу:**<br>
# **В таблицу добавлено расчеты следующих параметров:**
# * цена квадратного метра;
# * день недели, месяц и год публикации объявления;
# * этаж квартиры; варианты — первый, последний, другой;
# * соотношение жилой и общей площади, отношение площади кухни к общей.
#
# **Вывод по пункту 4 - Исследовательский анализ данных:**<br>
# **Вывод по пункту 4.1 - Изучение параметров: площадь, цена, число комнат, высота потолков. Построение гистограмм для каждого параметра.**
# **Вывод по параметру - площадь:**<br>
# У параметра нормальное распределение значений с характерными пиками в районе 30кв.м., 45кв.м., 55кв.м. и далее.<br>
# Эти пики объясняются квартирностью то есть пик в районе 30кв.м. это однокомнатные квартиры, 45кв.м. это двухкомнатные квартиры и т.д.<br>
#
# **Вывод по параметру - цена:**<br>
# У параметра видим нормальное распределение, без аномалий, с наличием пик связанных с тем, что люди при установлении цены квартиры округляли цены.<br>
#
# **Вывод по параметру - комнаты:**<br>
# По гистограмме видим нормальное распределение, без аномалий.<br>
# Медианное значение 2.0
#
# **Вывод по параметру - высота потолка:**<br>
# По гистограмме видим нормальное распределение, без аномалий.<br>
# Медианное значение 2.6
#
# **Вывод по пункту 4.2 - Изучение время продажи квартиры. Построение гистограммы. Расчет среднего и медианы. Анализ процесса продажи.**
# Медианное время продажи квартиры: 114.0
# Среднее время продажи квартиры: 195.7
# Анализ процесса продажи:
# Первые 5 дней рассматриваем как техническое закрытие объявления;<br>
# Первый квартиль - 44 дня рассматриваем как сверхбыстрая продажа;<br>
# Внутри ящика - от 44 дней до 258 дней нормальная продажа;<br>
# После 3 квартиля - от 258 дней необычно долгие продажи.<br>
#
# **Вывод по пункту 4.3 - Изучение время продажи квартиры. Построение гистограммы. Расчет среднего и медианы. Анализ процесса продажи.**
# Из следующих факторов:
# - last_price;
# - year_exposition;
# - month_exposition;
# - weekday_exposition;
# - rooms;
# - total_area;
# - cityCenters_nearest;<br>
#
# на стоимость квартиры влияют:<br>
# * Чем больше площадь квартиры тем выше цена - коэффициент корреляции 0.65;
# * Чем дальше от центра находится квартира тем меньше цена - коэффициент корреляции (-0.21);
# * Стоимость квадратного метра падает с 2014 года до 2018 года и корректируется в 2019 году;
# * Выраженный тренд зависимости от месяца публикации объявления отсутствует;
# * В субботу публикуют объявления с более высокой стоимостью квартиры относительно всех остальных дней недели;
# * Стоимость квадратного метра на первом и последнем этаже выше чем в середине здания;
# * Чем больше комнат в квартире тем выше стоимость квадратного метра - коэффициент корреляции 0.36;.<br>
#
# Остальные параметры не влияют на стоимость квартиры.
#
# **Вывод по пункту 4.4 - Изучение время продажи квартиры. Построение гистограммы. Расчет среднего и медианы. Анализ процесса продажи.**
# Самый дорогой квадратный метр ожидаемо в Санкт-Петербурге, а самый дешевый в Выборге.
#
#
# **Вывод по пункту 4.5 - Определение центральной зоны Санкт-Петербурга.**
# Цена квадратного метра остается высокой вплоть до 7 км. включительно, далее идет резкий скачок по уменьшению стоимости квадратного метра, что говорит о том, что именно эта удаленность психологически воспринимается как не центр.<br>
# За центр принимаем удаленность до 7 км включительно.
#
# **Вывод по пункту 4.6 - Анализ сегмента квартир в центре. Изучение параметров: площадь, цена, число комнат, высота потолков. Изучение факторов влияющих на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Анализ отличий от общих выводов по всей базе.**
# **По параметру площадь:**<br>
# В центральной территории меньше квартир с площадью от 30кв.м. до 45кв.м., за то гораздо больше квартир от 50кв.м. до 100кв.м.. <br>
# Так же видим, что меньше влияет квартирность (меньше пик на определенных квадратных метрах), что вполне логично, так как в центре здания старше и не типовые как на окраинах.
#
# **По параметру цена:**<br>
# Медианная цена квартиры в центральной территории 9млн.руб., по всей территории 4.95млн.руб.
#
# **По параметру комнаты:**<br>
# Распределение показывает, что в центральной территории квартиры имеют больше комнат - в частности в центральной территории наибольшее количество квартир с 4 комнатами, а по всей территории наибольшее количество квартир с 2 комнатами.
#
# **По параметру высота потолка:**<br>
# Распределение показывает, что в центральной территории квартиры имеют более высокие потолки - в частности в центральной территории наибольшее количество квартир с потолками от 3м. до 4м., а по всей территории наибольшее количество квартир с потолками от 2м. до 3м., а квартиры с потолками от 3м. до 4м. составляют малую часть выборки.
#
# **Зависимость цены квартиры от количества комнат:**<br>
# Стоимость квартиры зависит от количества комнат для квартир в центре (Коэффициент корреляции: 0.34) сильно меньше, чем по всей территоррии (Коэффициент корреляции: 0.52).<br>
# Стоимость квадратного метра квартиры в центре с увеличением количества комнат увеличивается, когда стоимость квадратного метра квартиры по всей территории с увеличением количества комнат уменьшается.
#
# **Зависимость цены квартиры от этажа:**<br>
# В центре стоимость квадратного метра возрастает до 10 этажа, на 11 этаже резко падает и продолжает снижение до 18 этажа, и дальше снова переходит в рост, то есть имеет разнонаправленную динамику изменения цены квадратного метра при возрастании этажа, тогда как на значениях по всей территории видим возрастающий общий тренд при возрастании этажа.
#
# **Зависимость цены квартиры от даты:**<br>
# Зависимость цены квадратного метра от дня недели публикации на всей территории и в центральной территории отсутствует, кроме одной интересной особенности в центре в субботу публикуют объявления со стоимостью квадратного метра сильно выше обычного.<br>
#
# Цена квадратного метра квартир по всей территории немного колеблется в зависимости от месяца, но не имеет выраженной динамики, тогда как цена квадратного метра квартир в центре имеет три выраженных месяца, где стоимость квадратного метра выше, чем в среднем по месяцам это апрель, сентябрь и декабрь.<br>
#
# Цена квадратного метра в центре с 2014 года снижается до 2018 года, и возвращается в рост в 2019 году, а по всей территории цена квадратного метра снижается с 2014 года до 2016 года и переходит к восстановлению уже в 2017.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Очень подробный и хороший вывод. Правильно, что в общий вывод погрузил выводы, полученные в предыдущих шагах работы. Некоторые пункты надо будет скорректировать после рассмотрения медианных цен.</div>

# %% [markdown]
# <p>
# <div class="alert-info">
# <b>Поправлено!</b>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Теперь все круто. 👍</div>

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера:</b>
#
# У тебя получилась очень сильная работа, ты отлично справился с обработкой данных, приведением их к нужному типу и исследовательским анализом.
#
# Мне очень понравились твои подробные и структурированные выводы, а также очень подробный общий вывод.
#
# Критических замечаний по твоему проекту у меня нет. Посмотри только "желтые" комментарии, а также нужно будет скорректировать некоторые пункты в выводах.
#
# Буду ждать твой доработанный проект.</div>

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера V2:</b>
#
# Спасибо, что отработал желтые замечания, получилась очень хорошая работа. Я написал в тексте как вижу визуализацию по медианным ценам.
#
# Успехов в дальнейшем обучении. 🤝</div>

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод

# %% [markdown]
# <img src="Снимок экрана 2022-03-31 в 23.14.47.png">
